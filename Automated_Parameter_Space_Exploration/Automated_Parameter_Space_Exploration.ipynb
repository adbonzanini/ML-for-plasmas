# %% [markdown]
# # Automated_Parameter_Space_Exploration
#
# Written by: Ketong Shao and Angelo D. Bonzanini
#
# Date: October 2021
#
# * Use the trained DNN, representing the pin-to-pin plasma setup
# * Bayesian optimization for parameter space exploration

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.python.framework import ops

seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)

from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras.layers import Dense, Dropout, Flatten

from sklearn.preprocessing import MinMaxScaler

# %%
# Load the experimental data
df = pd.read_csv('pintopindata.csv')

# calculate the discharge power
outpower = (np.array(df['Vdis'])*np.array(df['mA'])).reshape(-1,1)

# calculate the NOx production rate
outproduction = np.sum(np.array(df[['NO','NO2','HONO']]),axis=1).reshape(-1,1)*((np.array(df['slm'])+np.array(df['diluted'])).reshape(-1,1))

# build the outputs data
outputs = np.concatenate((outproduction,outpower),axis=1)
# extract the operating experimental parameters as inputs
inputs = np.array(df[['mA','O2frac','mm','slm']])

# shuffle the data, which is necessary for machine learning model training
np.random.seed(42)
index = list(range(len(inputs)))
np.random.shuffle(index)

outputs = outputs[index,:]
inputs = inputs[index,:]

# %%
# Scaler construction
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaler = scaler_x.fit(inputs)
X_scaler = scaler_y.fit(outputs)

# %%
# Load the trained DNN, which will represent the pin-to-pin setup
Pintopin_model = tf.keras.models.load_model('Pintopin_DNN_model')

# %% [markdown]
# ## Bayesian optimization for parameter space exploration

# %%
# Necessary packages installation and importing
! pip install scikit-optimize
import skopt
from skopt import gbrt_minimize, gp_minimize
from skopt.utils import use_named_args
from skopt.space import Real, Categorical, Integer
# Out:
# Requirement already satisfied: scikit-optimize in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (0.17.0)
# Requirement already satisfied: pyaml>=16.9 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (20.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)
# Requirement already satisfied: PyYAML in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from pyaml>=16.9->scikit-optimize) (5.3.1)

# %%
# Define the parameter space to explore

dim_mA = Real(low=20, high=70, prior='uniform',
                         name='mA')

dim_O2frac = Real(low=0, high=0.2095, prior='uniform',name='O2frac') 

dim_mm = Real(low=2, high=15, prior='uniform',name='mm') 

dim_slm = Real(low=0.5, high=7, prior='uniform',name='slm')


dimensions = [dim_mA,
              dim_O2frac,
              dim_mm,
              dim_slm
              ]

# initial value, from which the Bayesian optimization starts
default_parameters = [60, 0.11, 10.0, 6.0]

# %%
@use_named_args(dimensions=dimensions)
def inverse_loss_obj(mA,O2frac,mm,slm):
    input_x = np.array([mA,O2frac,mm,slm]).reshape(1,-1)
    input_norm = scaler_x.transform(input_x)
    output_now = scaler_y.inverse_transform(Pintopin_model.predict(input_norm)).reshape(-1)
    # the edge situations are not included in the data used in DNN training,
    # therefore, here needs some manual efforts to exclude them.
    if output_now[0] <= 0:
        a = 0.1
    else:
        a = output_now[0]

    if output_now[1] <= 0:
        b = 0.1
    else:
        b = output_now[1]

    current_v = b/a*60*24*1e-3/(14*2.5*1e-6) # necessary factors converting the unit to MJ/tN
    print('current energy per NOx (energy consumption) is {}'.format(current_v), 'MJ/tN')
    return current_v

# %%
inverse_result = gp_minimize(func=inverse_loss_obj,
                            dimensions=dimensions,
                            n_calls=150, 
                            noise= 1e-8,
                            n_jobs=-1,
                            acq_func="EI",
                            x0=default_parameters,)
                            #random_state=42)
# Out:
# current energy per NOx (energy consumption) is 406.31673165730075 MJ/tN
# current energy per NOx (energy consumption) is 355.51546301160545 MJ/tN
# current energy per NOx (energy consumption) is 373.62554669380194 MJ/tN
# current energy per NOx (energy consumption) is 1136.852834905897 MJ/tN
# current energy per NOx (energy consumption) is 397.0044084957668 MJ/tN
# current energy per NOx (energy consumption) is 1109.6873453685216 MJ/tN
# current energy per NOx (energy consumption) is 1379.0264981133598 MJ/tN
# current energy per NOx (energy consumption) is 361.85482570103244 MJ/tN
# current energy per NOx (energy consumption) is 460.07436939648227 MJ/tN
# current energy per NOx (energy consumption) is 831.8004523004805 MJ/tN
# current energy per NOx (energy consumption) is 1457.6353005000526 MJ/tN
# current energy per NOx (energy consumption) is 485.1665113653456 MJ/tN
# current energy per NOx (energy consumption) is 331.9964366299766 MJ/tN
# current energy per NOx (energy consumption) is 507.8342429229192 MJ/tN
# current energy per NOx (energy consumption) is 445.25374685015004 MJ/tN
# current energy per NOx (energy consumption) is 826.2073567935399 MJ/tN
# current energy per NOx (energy consumption) is 362.4527284077236 MJ/tN
# current energy per NOx (energy consumption) is 341.416814497539 MJ/tN
# current energy per NOx (energy consumption) is 449.8483325753894 MJ/tN
# current energy per NOx (energy consumption) is 386.34496501513894 MJ/tN
# current energy per NOx (energy consumption) is 422.06984332629617 MJ/tN
# current energy per NOx (energy consumption) is 754.4450845037189 MJ/tN
# current energy per NOx (energy consumption) is 428.5404809883663 MJ/tN
# current energy per NOx (energy consumption) is 335.13611555099493 MJ/tN
# current energy per NOx (energy consumption) is 358.79488502229964 MJ/tN
# current energy per NOx (energy consumption) is 464.8630321025849 MJ/tN
# current energy per NOx (energy consumption) is 336.0132745334081 MJ/tN
# current energy per NOx (energy consumption) is 309.29385551384524 MJ/tN
# current energy per NOx (energy consumption) is 313.9095540557589 MJ/tN
# current energy per NOx (energy consumption) is 310.41099556854795 MJ/tN
# current energy per NOx (energy consumption) is 311.98010700089594 MJ/tN
# current energy per NOx (energy consumption) is 326.4006589140211 MJ/tN
# current energy per NOx (energy consumption) is 381.6150043691908 MJ/tN
# current energy per NOx (energy consumption) is 335.0262216159276 MJ/tN
# current energy per NOx (energy consumption) is 1301.1264119829452 MJ/tN
# current energy per NOx (energy consumption) is 376.8406340054104 MJ/tN
# current energy per NOx (energy consumption) is 509.42881618227284 MJ/tN
# current energy per NOx (energy consumption) is 1138.2620675223216 MJ/tN
# current energy per NOx (energy consumption) is 387.0054398264204 MJ/tN
# current energy per NOx (energy consumption) is 367.94976251465937 MJ/tN
# current energy per NOx (energy consumption) is 396.2563787187849 MJ/tN
# current energy per NOx (energy consumption) is 331.72288962772916 MJ/tN
# current energy per NOx (energy consumption) is 311.9332449776786 MJ/tN
# current energy per NOx (energy consumption) is 296.2684163025448 MJ/tN
# current energy per NOx (energy consumption) is 301.9821154219764 MJ/tN
# current energy per NOx (energy consumption) is 352.66929439135964 MJ/tN
# current energy per NOx (energy consumption) is 304.2743695633752 MJ/tN
# current energy per NOx (energy consumption) is 343.14369729587014 MJ/tN
# current energy per NOx (energy consumption) is 355.19923056874956 MJ/tN
# current energy per NOx (energy consumption) is 296.88679959092826 MJ/tN
# current energy per NOx (energy consumption) is 307.3167800903321 MJ/tN
# current energy per NOx (energy consumption) is 298.44905223165244 MJ/tN
# current energy per NOx (energy consumption) is 658.3459036690849 MJ/tN
# current energy per NOx (energy consumption) is 326.3486623764038 MJ/tN
# current energy per NOx (energy consumption) is 296.52102291584015 MJ/tN
# current energy per NOx (energy consumption) is 295.6913581916264 MJ/tN
# current energy per NOx (energy consumption) is 313.84790156568806 MJ/tN
# current energy per NOx (energy consumption) is 296.8087856258665 MJ/tN
# current energy per NOx (energy consumption) is 304.625432406153 MJ/tN
# current energy per NOx (energy consumption) is 604.7071261065347 MJ/tN
# current energy per NOx (energy consumption) is 297.870193208967 MJ/tN
# current energy per NOx (energy consumption) is 358.63437397139415 MJ/tN
# current energy per NOx (energy consumption) is 316.7682524238314 MJ/tN
# current energy per NOx (energy consumption) is 360.11771219117304 MJ/tN
# current energy per NOx (energy consumption) is 390.964150428772 MJ/tN
# current energy per NOx (energy consumption) is 340.9404158592224 MJ/tN
# current energy per NOx (energy consumption) is 305.3445518016816 MJ/tN
# current energy per NOx (energy consumption) is 348.2233030455453 MJ/tN
# current energy per NOx (energy consumption) is 320.5973165375846 MJ/tN
# current energy per NOx (energy consumption) is 299.4252613612584 MJ/tN
# current energy per NOx (energy consumption) is 337.1202605111259 MJ/tN
# current energy per NOx (energy consumption) is 322.4109879561833 MJ/tN
# current energy per NOx (energy consumption) is 295.7986082349505 MJ/tN
# current energy per NOx (energy consumption) is 297.36890750271937 MJ/tN
# current energy per NOx (energy consumption) is 302.23876450742995 MJ/tN
# current energy per NOx (energy consumption) is 295.7683950662613 MJ/tN
# current energy per NOx (energy consumption) is 299.96398304189955 MJ/tN
# current energy per NOx (energy consumption) is 298.4779051371983 MJ/tN
# current energy per NOx (energy consumption) is 310.15712448528836 MJ/tN
# current energy per NOx (energy consumption) is 296.8250896249499 MJ/tN
# current energy per NOx (energy consumption) is 345.9894827433995 MJ/tN
# current energy per NOx (energy consumption) is 298.32900421960017 MJ/tN
# current energy per NOx (energy consumption) is 313.7742366109576 MJ/tN
# current energy per NOx (energy consumption) is 308.6968915803092 MJ/tN
# current energy per NOx (energy consumption) is 307.6797979218619 MJ/tN
# current energy per NOx (energy consumption) is 301.6082154853004 MJ/tN
# current energy per NOx (energy consumption) is 302.0315447023937 MJ/tN
# current energy per NOx (energy consumption) is 295.75151630810336 MJ/tN
# current energy per NOx (energy consumption) is 303.85201743670876 MJ/tN
# current energy per NOx (energy consumption) is 295.8174411739622 MJ/tN
# current energy per NOx (energy consumption) is 304.9020064728601 MJ/tN
# current energy per NOx (energy consumption) is 304.26216551235746 MJ/tN
# current energy per NOx (energy consumption) is 305.32418617180423 MJ/tN
# current energy per NOx (energy consumption) is 298.38602031980247 MJ/tN
# current energy per NOx (energy consumption) is 304.05362376144956 MJ/tN
# current energy per NOx (energy consumption) is 332.5906991958619 MJ/tN
# current energy per NOx (energy consumption) is 306.4572470528739 MJ/tN
# current energy per NOx (energy consumption) is 311.4348139081683 MJ/tN
# current energy per NOx (energy consumption) is 300.1718159232821 MJ/tN
# current energy per NOx (energy consumption) is 300.4432363169534 MJ/tN
# current energy per NOx (energy consumption) is 310.4660191706249 MJ/tN
# current energy per NOx (energy consumption) is 317.10243650845126 MJ/tN
# current energy per NOx (energy consumption) is 296.79805678980694 MJ/tN
# current energy per NOx (energy consumption) is 305.52828311920166 MJ/tN
# current energy per NOx (energy consumption) is 296.1980657918113 MJ/tN
# current energy per NOx (energy consumption) is 23642.914090837752 MJ/tN
# current energy per NOx (energy consumption) is 308.6459487676621 MJ/tN
# current energy per NOx (energy consumption) is 315.96129068306516 MJ/tN
# current energy per NOx (energy consumption) is 322.22457442964827 MJ/tN
# current energy per NOx (energy consumption) is 430.8418929576874 MJ/tN
# current energy per NOx (energy consumption) is 1406.650951930455 MJ/tN
# current energy per NOx (energy consumption) is 4604289.289202009 MJ/tN
# current energy per NOx (energy consumption) is 964.8895178522383 MJ/tN
# current energy per NOx (energy consumption) is 2551.381894520351 MJ/tN
# current energy per NOx (energy consumption) is 2571.7660699571884 MJ/tN
# current energy per NOx (energy consumption) is 1022.1447944641114 MJ/tN
# current energy per NOx (energy consumption) is 2057.283895356315 MJ/tN
# current energy per NOx (energy consumption) is 2980.7759693690714 MJ/tN
# current energy per NOx (energy consumption) is 1517.914652824402 MJ/tN
# current energy per NOx (energy consumption) is 2780.8536120823455 MJ/tN
# current energy per NOx (energy consumption) is 1316.052828516279 MJ/tN
# current energy per NOx (energy consumption) is 1192.6029324531555 MJ/tN
# current energy per NOx (energy consumption) is 3505.1009314400812 MJ/tN
# current energy per NOx (energy consumption) is 571.1520782538823 MJ/tN
# current energy per NOx (energy consumption) is 3831.448214394706 MJ/tN
# current energy per NOx (energy consumption) is 1456.1153309685844 MJ/tN
# current energy per NOx (energy consumption) is 1647.6029838834493 MJ/tN
# current energy per NOx (energy consumption) is 616.8204035077777 MJ/tN
# current energy per NOx (energy consumption) is 1503.104260989598 MJ/tN
# current energy per NOx (energy consumption) is 966.1768249103002 MJ/tN
# current energy per NOx (energy consumption) is 1175.2603820392064 MJ/tN
# current energy per NOx (energy consumption) is 1162.7993753978185 MJ/tN
# current energy per NOx (energy consumption) is 452.8856660638537 MJ/tN
# current energy per NOx (energy consumption) is 1577.7792590005058 MJ/tN
# current energy per NOx (energy consumption) is 1369.5960044860842 MJ/tN
# current energy per NOx (energy consumption) is 429.9910196236202 MJ/tN
# current energy per NOx (energy consumption) is 1581.6091469355995 MJ/tN
# current energy per NOx (energy consumption) is 6584.6974509102965 MJ/tN
# current energy per NOx (energy consumption) is 1431.073001452855 MJ/tN
# current energy per NOx (energy consumption) is 2076.596566608974 MJ/tN
# current energy per NOx (energy consumption) is 858.3748596055168 MJ/tN
# current energy per NOx (energy consumption) is 1583.2376309803556 MJ/tN
# current energy per NOx (energy consumption) is 1000.7258994238719 MJ/tN
# current energy per NOx (energy consumption) is 1333.58941759382 MJ/tN
# current energy per NOx (energy consumption) is 1855.7220186506 MJ/tN
# current energy per NOx (energy consumption) is 1538.2557596479144 MJ/tN
# current energy per NOx (energy consumption) is 844.9098638125829 MJ/tN
# current energy per NOx (energy consumption) is 842.0720100402833 MJ/tN
# current energy per NOx (energy consumption) is 488.06122796876093 MJ/tN
# current energy per NOx (energy consumption) is 1317.3637390136719 MJ/tN

# %%
# Print the found best MSE
print('Minimal energy consumption found:', inverse_result.fun,'MJ/tN',)
print('-----------------------------------------------')
# Print the corresponding hyperparameter values
print('Operating parameter values:', inverse_result.x)
print('-----------------------------------------------')
print('Corresponding to:','\n',
      'Applied current:', inverse_result.x[0],'mA\n',
      'Oxygen mole fraction:', inverse_result.x[1],'%\n',
      'Pin-to-pin discharge distance:', inverse_result.x[2],'mm\n',
      'Flowrate:', inverse_result.x[3],'slm\n',)
# Out:
# Minimal energy consumption found: 295.6913581916264 MJ/tN
# -----------------------------------------------
# Operating parameter values: [40.37665133723526, 0.2095, 12.967367368914676, 7.0]
# -----------------------------------------------
# Corresponding to:
#  Applied current: 40.37665133723526 mA
#  Oxygen mole fraction: 0.2095 %
#  Pin-to-pin discharge distance: 12.967367368914676 mm
#  Flowrate: 7.0 slm
