# %% [markdown]
# # Automated_Parameter_Space_Exploration
#
# Written by: Ketong Shao and Angelo D. Bonzanini
#
# Date: October 2021
#
# * Use the trained DNN, representing the pin-to-pin plasma setup
# * Bayesian optimization for parameter space exploration

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.python.framework import ops

seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)

from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras.layers import Dense, Dropout, Flatten

from sklearn.preprocessing import MinMaxScaler

# %%
# Load the experimental data
df = pd.read_csv('pintopindata.csv')

# calculate the discharge power
outpower = (np.array(df['Vdis'])*np.array(df['mA'])).reshape(-1,1)

# calculate the NOx production rate
outproduction = np.sum(np.array(df[['NO','NO2','HONO']]),axis=1).reshape(-1,1)*((np.array(df['slm'])+np.array(df['diluted'])).reshape(-1,1))

# build the outputs data
outputs = np.concatenate((outproduction,outpower),axis=1)
# extract the operating experimental parameters as inputs
inputs = np.array(df[['mA','O2frac','mm','slm']])

# shuffle the data, which is necessary for machine learning model training
np.random.seed(42)
index = list(range(len(inputs)))
np.random.shuffle(index)

outputs = outputs[index,:]
inputs = inputs[index,:]

# %%
# Scaler construction
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaler = scaler_x.fit(inputs)
X_scaler = scaler_y.fit(outputs)

# %%
# Load the trained DNN, which will represent the pin-to-pin setup
Pintopin_model = tf.keras.models.load_model('Pintopin_DNN_model')

# %% [markdown]
# ## Bayesian optimization for parameter space exploration

# %%
# Necessary packages installation and importing
! pip install scikit-optimize
import skopt
from skopt import gbrt_minimize, gp_minimize
from skopt.utils import use_named_args
from skopt.space import Real, Categorical, Integer
# Out:
# Requirement already satisfied: scikit-optimize in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (0.17.0)
# Requirement already satisfied: pyaml>=16.9 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-optimize) (20.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)
# Requirement already satisfied: PyYAML in /Users/shaoketong/anaconda3/lib/python3.8/site-packages (from pyaml>=16.9->scikit-optimize) (5.3.1)

# %%
# Define the parameter space to explore

dim_mA = Real(low=20, high=70, prior='uniform',
                         name='mA')

dim_O2frac = Real(low=0, high=0.2095, prior='uniform',name='O2frac') 

dim_mm = Real(low=2, high=15, prior='uniform',name='mm') 

dim_slm = Real(low=0.5, high=7, prior='uniform',name='slm')


dimensions = [dim_mA,
              dim_O2frac,
              dim_mm,
              dim_slm
              ]

# initial value, from which the Bayesian optimization starts
default_parameters = [60, 0.11, 10.0, 6.0]

# %%
@use_named_args(dimensions=dimensions)
def inverse_loss_obj(mA,O2frac,mm,slm):
    input_x = np.array([mA,O2frac,mm,slm]).reshape(1,-1)
    input_norm = scaler_x.transform(input_x)
    output_now = scaler_y.inverse_transform(Pintopin_model.predict(input_norm)).reshape(-1)
    # the edge situations are not included in the data used in DNN training,
    # therefore, here needs some manual efforts to exclude them.
    if output_now[0] <= 0:
        a = 0.1
    else:
        a = output_now[0]

    if output_now[1] <= 0:
        b = 0.1
    else:
        b = output_now[1]

    current_v = b/a*60*24*1e-3/(14*2.5*1e-6) # necessary factors converting the unit to MJ/tN
    print('current energy per NOx (energy consumption) is {}'.format(current_v), 'MJ/tN')
    return current_v

# %%
inverse_result = gp_minimize(func=inverse_loss_obj,
                            dimensions=dimensions,
                            n_calls=150, 
                            noise= 1e-8,
                            n_jobs=-1,
                            acq_func="EI",
                            x0=default_parameters,)
                            #random_state=42)
# Out:
# current energy per NOx (energy consumption) is 406.31673165730075 MJ/tN
# current energy per NOx (energy consumption) is 2543.3533532278884 MJ/tN
# current energy per NOx (energy consumption) is 426.43226470266075 MJ/tN
# current energy per NOx (energy consumption) is 1493.3146578924998 MJ/tN
# current energy per NOx (energy consumption) is 715.2846796172006 MJ/tN
# current energy per NOx (energy consumption) is 894.9689269065858 MJ/tN
# current energy per NOx (energy consumption) is 412.7021900245122 MJ/tN
# current energy per NOx (energy consumption) is 344.2275396415166 MJ/tN
# current energy per NOx (energy consumption) is 677.8766768319266 MJ/tN
# current energy per NOx (energy consumption) is 409.70823168754583 MJ/tN
# current energy per NOx (energy consumption) is 611.3551727363042 MJ/tN
# current energy per NOx (energy consumption) is 501.8700446401324 MJ/tN
# current energy per NOx (energy consumption) is 405.1640331745148 MJ/tN
# current energy per NOx (energy consumption) is 387.3248909200941 MJ/tN
# current energy per NOx (energy consumption) is 331.9964366299766 MJ/tN
# current energy per NOx (energy consumption) is 445.25374685015004 MJ/tN
# current energy per NOx (energy consumption) is 375.58693119457797 MJ/tN
# current energy per NOx (energy consumption) is 350.06276198795865 MJ/tN
# current energy per NOx (energy consumption) is 387.4042459896633 MJ/tN
# current energy per NOx (energy consumption) is 445.4998203686306 MJ/tN
# current energy per NOx (energy consumption) is 414.25005452973505 MJ/tN
# current energy per NOx (energy consumption) is 434.25174696104875 MJ/tN
# current energy per NOx (energy consumption) is 444.5187449455262 MJ/tN
# current energy per NOx (energy consumption) is 379.24121107373924 MJ/tN
# current energy per NOx (energy consumption) is 400.0558810574668 MJ/tN
# current energy per NOx (energy consumption) is 466.20011329650885 MJ/tN
# current energy per NOx (energy consumption) is 1833.8246175221036 MJ/tN
# current energy per NOx (energy consumption) is 1142.565097127642 MJ/tN
# current energy per NOx (energy consumption) is 366.01056371416365 MJ/tN
# current energy per NOx (energy consumption) is 1056.0167261532376 MJ/tN
# current energy per NOx (energy consumption) is 458.0404886177608 MJ/tN
# current energy per NOx (energy consumption) is 442.90945785386225 MJ/tN
# current energy per NOx (energy consumption) is 338.7298541409629 MJ/tN
# current energy per NOx (energy consumption) is 417.29669911520824 MJ/tN
# current energy per NOx (energy consumption) is 323.179019348962 MJ/tN
# current energy per NOx (energy consumption) is 326.14263040678844 MJ/tN
# current energy per NOx (energy consumption) is 337.3576743262155 MJ/tN
# current energy per NOx (energy consumption) is 338.02240235464916 MJ/tN
# current energy per NOx (energy consumption) is 312.1572860649654 MJ/tN
# current energy per NOx (energy consumption) is 410.76705285481046 MJ/tN
# current energy per NOx (energy consumption) is 406.3906456742968 MJ/tN
# current energy per NOx (energy consumption) is 440.940409898758 MJ/tN
# current energy per NOx (energy consumption) is 409.82073119708474 MJ/tN
# current energy per NOx (energy consumption) is 416.70787760189603 MJ/tN
# current energy per NOx (energy consumption) is 369.45850508553644 MJ/tN
# current energy per NOx (energy consumption) is 472.56488033703397 MJ/tN
# current energy per NOx (energy consumption) is 319.3862800087248 MJ/tN
# current energy per NOx (energy consumption) is 1085.8679498944966 MJ/tN
# current energy per NOx (energy consumption) is 344.76819634437567 MJ/tN
# current energy per NOx (energy consumption) is 379.43084325109214 MJ/tN
# current energy per NOx (energy consumption) is 487.57662943431313 MJ/tN
# current energy per NOx (energy consumption) is 398.6610174179078 MJ/tN
# current energy per NOx (energy consumption) is 486.2626535551889 MJ/tN
# current energy per NOx (energy consumption) is 312.0899817773274 MJ/tN
# current energy per NOx (energy consumption) is 328.77931850297114 MJ/tN
# current energy per NOx (energy consumption) is 309.22639795712064 MJ/tN
# current energy per NOx (energy consumption) is 349.6156377451761 MJ/tN
# current energy per NOx (energy consumption) is 326.59381628036505 MJ/tN
# current energy per NOx (energy consumption) is 435.0105438913618 MJ/tN
# current energy per NOx (energy consumption) is 331.82228463036677 MJ/tN
# current energy per NOx (energy consumption) is 310.1117376770292 MJ/tN
# current energy per NOx (energy consumption) is 310.76966438974654 MJ/tN
# current energy per NOx (energy consumption) is 319.85375072274894 MJ/tN
# current energy per NOx (energy consumption) is 321.4715250900814 MJ/tN
# current energy per NOx (energy consumption) is 354.4684052467347 MJ/tN
# current energy per NOx (energy consumption) is 311.9925409555436 MJ/tN
# current energy per NOx (energy consumption) is 310.72308974606653 MJ/tN
# current energy per NOx (energy consumption) is 351.9337943622045 MJ/tN
# current energy per NOx (energy consumption) is 731.1939341681345 MJ/tN
# current energy per NOx (energy consumption) is 320.23993134498596 MJ/tN
# current energy per NOx (energy consumption) is 365.4972272259849 MJ/tN
# current energy per NOx (energy consumption) is 309.7645448786872 MJ/tN
# current energy per NOx (energy consumption) is 309.54711352075856 MJ/tN
# current energy per NOx (energy consumption) is 409.65627346720015 MJ/tN
# current energy per NOx (energy consumption) is 339.26307729312356 MJ/tN
# current energy per NOx (energy consumption) is 429.0004798344204 MJ/tN
# current energy per NOx (energy consumption) is 315.2889566762107 MJ/tN
# current energy per NOx (energy consumption) is 306.2244887862887 MJ/tN
# current energy per NOx (energy consumption) is 304.96804629053395 MJ/tN
# current energy per NOx (energy consumption) is 316.0767789397921 MJ/tN
# current energy per NOx (energy consumption) is 303.1160767589297 MJ/tN
# current energy per NOx (energy consumption) is 301.2427261897496 MJ/tN
# current energy per NOx (energy consumption) is 299.3371316364834 MJ/tN
# current energy per NOx (energy consumption) is 298.09823845114033 MJ/tN
# current energy per NOx (energy consumption) is 659.8742263657707 MJ/tN
# current energy per NOx (energy consumption) is 346.40752417700634 MJ/tN
# current energy per NOx (energy consumption) is 298.1756776571274 MJ/tN
# current energy per NOx (energy consumption) is 298.22556674480444 MJ/tN
# current energy per NOx (energy consumption) is 296.85809995446886 MJ/tN
# current energy per NOx (energy consumption) is 302.5646337441036 MJ/tN
# current energy per NOx (energy consumption) is 296.1128290210452 MJ/tN
# current energy per NOx (energy consumption) is 345.0222398553576 MJ/tN
# current energy per NOx (energy consumption) is 415.09701950209484 MJ/tN
# current energy per NOx (energy consumption) is 646.7697194644384 MJ/tN
# current energy per NOx (energy consumption) is 295.91919268880577 MJ/tN
# current energy per NOx (energy consumption) is 372.7939469473703 MJ/tN
# current energy per NOx (energy consumption) is 300.677987081664 MJ/tN
# current energy per NOx (energy consumption) is 320.89109505925865 MJ/tN
# current energy per NOx (energy consumption) is 372.2558575017112 MJ/tN
# current energy per NOx (energy consumption) is 298.2457407883236 MJ/tN
# current energy per NOx (energy consumption) is 319.5060214826039 MJ/tN
# current energy per NOx (energy consumption) is 343.58082073075434 MJ/tN
# current energy per NOx (energy consumption) is 684.2972721372332 MJ/tN
# current energy per NOx (energy consumption) is 348.5081919601986 MJ/tN
# current energy per NOx (energy consumption) is 295.8198551620756 MJ/tN
# current energy per NOx (energy consumption) is 305.66130152770455 MJ/tN
# current energy per NOx (energy consumption) is 296.5373460735594 MJ/tN
# current energy per NOx (energy consumption) is 296.3889049632209 MJ/tN
# current energy per NOx (energy consumption) is 295.9382746900831 MJ/tN
# current energy per NOx (energy consumption) is 295.6952090774264 MJ/tN
# current energy per NOx (energy consumption) is 300.30230539185663 MJ/tN
# current energy per NOx (energy consumption) is 295.7104785101755 MJ/tN
# current energy per NOx (energy consumption) is 303.24327094214306 MJ/tN
# current energy per NOx (energy consumption) is 302.42523550987244 MJ/tN
# current energy per NOx (energy consumption) is 295.69764222417564 MJ/tN
# current energy per NOx (energy consumption) is 295.78994853155956 MJ/tN
# current energy per NOx (energy consumption) is 303.9709542478834 MJ/tN
# current energy per NOx (energy consumption) is 295.7801584686552 MJ/tN
# current energy per NOx (energy consumption) is 295.69229696478163 MJ/tN
# current energy per NOx (energy consumption) is 296.13359698227475 MJ/tN
# current energy per NOx (energy consumption) is 336.50473185947965 MJ/tN
# current energy per NOx (energy consumption) is 296.4404608522143 MJ/tN
# current energy per NOx (energy consumption) is 300.44151203972956 MJ/tN
# current energy per NOx (energy consumption) is 295.70241272449493 MJ/tN
# current energy per NOx (energy consumption) is 295.7718627793449 MJ/tN
# current energy per NOx (energy consumption) is 295.71806532996044 MJ/tN
# current energy per NOx (energy consumption) is 304.23358082771307 MJ/tN
# current energy per NOx (energy consumption) is 295.6948450633458 MJ/tN
# current energy per NOx (energy consumption) is 305.0295455115182 MJ/tN
# current energy per NOx (energy consumption) is 298.0645767280034 MJ/tN
# current energy per NOx (energy consumption) is 330.6727281638554 MJ/tN
# current energy per NOx (energy consumption) is 297.9112693241665 MJ/tN
# current energy per NOx (energy consumption) is 304.91769739559726 MJ/tN
# current energy per NOx (energy consumption) is 296.6878371579307 MJ/tN
# current energy per NOx (energy consumption) is 302.88701610905787 MJ/tN
# current energy per NOx (energy consumption) is 317.65633182866236 MJ/tN
# current energy per NOx (energy consumption) is 299.07661250659396 MJ/tN
# current energy per NOx (energy consumption) is 299.0202286413738 MJ/tN
# current energy per NOx (energy consumption) is 301.40132137707303 MJ/tN
# current energy per NOx (energy consumption) is 305.8915116957256 MJ/tN
# current energy per NOx (energy consumption) is 295.9275650126594 MJ/tN
# current energy per NOx (energy consumption) is 319.0907963684627 MJ/tN
# current energy per NOx (energy consumption) is 307.81603498118267 MJ/tN
# current energy per NOx (energy consumption) is 305.7554853813989 MJ/tN
# current energy per NOx (energy consumption) is 308.6551832301276 MJ/tN
# current energy per NOx (energy consumption) is 320.2270759003503 MJ/tN
# current energy per NOx (energy consumption) is 295.7596395696913 MJ/tN
# current energy per NOx (energy consumption) is 313.34707566670016 MJ/tN
# current energy per NOx (energy consumption) is 295.84286468369623 MJ/tN
# current energy per NOx (energy consumption) is 296.00490842546736 MJ/tN

# %%
# Print the found best MSE
print('Minimal energy consumption found:', inverse_result.fun,'MJ/tN',)
print('-----------------------------------------------')
# Print the corresponding hyperparameter values
print('Operating parameter values:', inverse_result.x)
print('-----------------------------------------------')
print('Corresponding to:','\n',
      'Applied current:', inverse_result.x[0],'mA\n',
      'Oxygen mole fraction:', inverse_result.x[1],'%\n',
      'Pin-to-pin discharge distance:', inverse_result.x[2],'mm\n',
      'Flowrate:', inverse_result.x[3],'slm\n',)
# Out:
# Minimal energy consumption found: 295.69229696478163 MJ/tN
# -----------------------------------------------
# Operating parameter values: [40.505725580398874, 0.2095, 12.883727185746547, 7.0]
# -----------------------------------------------
# Corresponding to:
#  Applied current: 40.505725580398874 mA
#  Oxygen mole fraction: 0.2095 %
#  Pin-to-pin discharge distance: 12.883727185746547 mm
#  Flowrate: 7.0 slm
